# %% [markdown]
# <a href="https://colab.research.google.com/github/chanikyaramireddy/Hunar-Intern/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def encrypt(text, shift):
    result = ""
    for char in text:
        if char.isalpha():
            shift_amount = shift % 26
            if char.islower():
                result += chr((ord(char) - 97 + shift_amount) % 26 + 97)
            else:
                result += chr((ord(char) - 65 + shift_amount) % 26 + 65)
        else:
            result += char
    return result


def decrypt(text, shift):
    return encrypt(text, -shift)


# Main Program
print("=== Encryption / Decryption Tool ===")

while True:
    choice = input("\n1. Encrypt\n2. Decrypt\n3. Exit\nChoose option: ")

    if choice == "1":
        message = input("Enter message: ")
        shift = int(input("Enter shift value: "))
        print("Encrypted Message:", encrypt(message, shift))

    elif choice == "2":
        message = input("Enter message: ")
        shift = int(input("Enter shift value: "))
        print("Decrypted Message:", decrypt(message, shift))

    elif choice == "3":
        print("Exiting...")
        break

    else:
        print("Invalid choice!")
